# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

x = np.array([8.9,10.82,12.3,14.4]).reshape((-1, 1))
y = np.array([36,30,25,21])

# %%
plt.plot(x,y)
plt.show()

# %%
model = LinearRegression().fit(x, y)

# %%
print('intercept:', model.intercept_)

print('slope:', model.coef_)
# Out:
# intercept: 60.079780383650785
# slope: [-2.7643068]
